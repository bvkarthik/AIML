# %%
import numpy as np
import pandas as pd

# %%
laliga = pd.read_csv('Laliga.csv')

# %%
laliga.columns = laliga.iloc[0]

# %%
laliga.drop(laliga.index[0], inplace=True)
laliga.reset_index(level=0,inplace=True)
laliga
# Out:
# 0   index Pos                 Team Seasons Points GamesPlayed GamesWon  \
# 0       1   1          Real Madrid      86   4385        2762     1647
# 1       2   2            Barcelona      86   4262        2762     1581
# 2       3   3      Atletico Madrid      80   3442        2614     1241
# 3       4   4             Valencia      82   3386        2664     1187
# 4       5   5      Athletic Bilbao      86   3368        2762     1209
# 5       6   6              Sevilla      73   2819        2408      990
# 6       7   7             Espanyol      82   2792        2626      948
# 7       8   8        Real Sociedad      70   2573        2302      864
# 8       9   9             Zaragoza      58   2109        1986      698
# 9      10  10           Real Betis      51   1884        1728      606
# 10     11  11  Deportivo La Coruna      45   1814        1530      563
# 11     12  12           Celta Vigo      51   1789        1698      586
# ...

# %%
laliga.replace(
    to_replace=['-'],
    value='0',
    inplace=True
)

# %%
laliga
# Out:
# 0   index Pos                 Team Seasons Points GamesPlayed GamesWon  \
# 0       1   1          Real Madrid      86   4385        2762     1647
# 1       2   2            Barcelona      86   4262        2762     1581
# 2       3   3      Atletico Madrid      80   3442        2614     1241
# 3       4   4             Valencia      82   3386        2664     1187
# 4       5   5      Athletic Bilbao      86   3368        2762     1209
# 5       6   6              Sevilla      73   2819        2408      990
# 6       7   7             Espanyol      82   2792        2626      948
# 7       8   8        Real Sociedad      70   2573        2302      864
# 8       9   9             Zaragoza      58   2109        1986      698
# 9      10  10           Real Betis      51   1884        1728      606
# 10     11  11  Deportivo La Coruna      45   1814        1530      563
# 11     12  12           Celta Vigo      51   1789        1698      586
# ...

# %%
Debut1 = ((laliga['Debut']>='1930')&(laliga['Debut']<='1980'))

# %%
Team1 = laliga[((laliga['Debut']>='1930')&(laliga['Debut']<='1980'))]
print("The teams which have started playing from 1930 to 1980 are as follows:")
Team1['Team']
# Out:
# The teams which have started playing from 1930 to 1980 are as follows:
# 3                Valencia
# 5                 Sevilla
# 8                Zaragoza
# 9              Real Betis
# 10    Deportivo La Coruna
# 11             Celta Vigo
# 12             Valladolid
# 14         Sporting Gijon
# 15                Osasuna
# 16                 Malaga
# 17                 Oviedo
# 18               Mallorca
# 19             Las Palmas
# 21                Granada
# 22         Rayo Vallecano
# 23                  Elche
# 25               Hercules
# 26               Tenerife
# 27                 Murcia
# 28                 Alaves
# 29                Levante
# 30              Salamanca
# 31               Sabadell
# 32                  Cadiz
# 34              Castellon
# 37                Cordoba
# 39             Recreativo
# 40              Burgos CF
# 41             Pontevedra
# 46              Gimnastic
# 49               Alcoyano
# 50                   Jaen
# 52             AD Almeria
# ...

# %%
laliga['Points'].astype(str).astype(int).nlargest(5)
# Out:
# 0    4385
# 1    4262
# 2    3442
# 3    3386
# 4    3368
# Name: Points, dtype: int64

# %%
indexp = laliga['Points'].astype(str).astype(int).nlargest(5).index
indexp
# Out:
# Int64Index([0, 1, 2, 3, 4], dtype='int64')

# %%
print("The top 5 teams with higest points are as follows:")
Top5 = laliga.iloc[indexp]
Top5['Team']
# Out:
# The top 5 teams with higest points are as follows:
# 0        Real Madrid
# 1          Barcelona
# 2    Atletico Madrid
# 3           Valencia
# 4    Athletic Bilbao
# Name: Team, dtype: object

# %%
def Goal_diff_count(Teams):
    return int(Teams[1])-int(Teams[2])

GoalDiff = laliga[['Team','GoalsFor','GoalsAgainst']].apply(lambda x: Goal_diff_count(x),axis=1)

# %%
print("The teams and their goal differences are as follows:")
for x in range(GoalDiff.count()):
    print(laliga.loc[x,'Team']+" goaldiff is "+str(GoalDiff[x]))
# Out:
# The teams and their goal differences are as follows:
# Real Madrid goaldiff is 2807
# Barcelona goaldiff is 2786
# Atletico Madrid goaldiff is 1225
# Valencia goaldiff is 929
# Athletic Bilbao goaldiff is 931
# Sevilla goaldiff is 307
# Espanyol goaldiff is -280
# Real Sociedad goaldiff is -2
# Zaragoza goaldiff is -164
# Real Betis goaldiff is -333
# Deportivo La Coruna goaldiff is -136
# Celta Vigo goaldiff is -346
# Valladolid goaldiff is -413
# Racing Santander goaldiff is -525
# Sporting Gijon goaldiff is -399
# Osasuna goaldiff is -334
# Malaga goaldiff is -342
# Oviedo goaldiff is -309
# Mallorca goaldiff is -189
# Las Palmas goaldiff is -399
# Villarreal goaldiff is 103
# Granada goaldiff is -338
# Rayo Vallecano goaldiff is -328
# Elche goaldiff is -272
# Getafe goaldiff is -113
# Hercules goaldiff is -334
# Tenerife goaldiff is -125
# Murcia goaldiff is -385
# Alaves goaldiff is -165
# Levante goaldiff is -202
# Salamanca goaldiff is -159
# Sabadell goaldiff is -228
# ...

# %%
MinGD = GoalDiff[0:60].min()
MaxGD = GoalDiff[0:60].max()

# %%
MinIN=GoalDiff[GoalDiff==MinGD].index
MaxIN=GoalDiff[GoalDiff==MaxGD].index

# %%
print(laliga.loc[MinIN,'Team'])
print(laliga.loc[MaxIN,'Team'])
# Out:
# 13    Racing Santander
# Name: Team, dtype: object
# 0    Real Madrid
# Name: Team, dtype: object

# %%
def Win_Percent(P):
    if int(P[1])!=0:
        return int(P[0])/int(P[1])
    else:
        return 0
laliga['Winning Percent'] = laliga[['GamesWon','GamesPlayed']].apply(lambda x: Win_Percent(x),axis=1)

# %%
laliga
# Out:
# 0   index Pos                 Team Seasons Points GamesPlayed GamesWon  \
# 0       1   1          Real Madrid      86   4385        2762     1647
# 1       2   2            Barcelona      86   4262        2762     1581
# 2       3   3      Atletico Madrid      80   3442        2614     1241
# 3       4   4             Valencia      82   3386        2664     1187
# 4       5   5      Athletic Bilbao      86   3368        2762     1209
# 5       6   6              Sevilla      73   2819        2408      990
# 6       7   7             Espanyol      82   2792        2626      948
# 7       8   8        Real Sociedad      70   2573        2302      864
# 8       9   9             Zaragoza      58   2109        1986      698
# 9      10  10           Real Betis      51   1884        1728      606
# 10     11  11  Deportivo La Coruna      45   1814        1530      563
# 11     12  12           Celta Vigo      51   1789        1698      586
# ...

# %%
indexpr = laliga['Winning Percent'].astype(str).astype(float).nlargest(5).index
indexpr
# Out:
# Int64Index([0, 1, 2, 3, 4], dtype='int64')

# %%
print("The top 5 teams with higest points are as follows:")
Top5 = laliga.iloc[indexpr]
Top5['Team']
# Out:
# The top 5 teams with higest points are as follows:
# 0        Real Madrid
# 1          Barcelona
# 2    Atletico Madrid
# 3           Valencia
# 4    Athletic Bilbao
# Name: Team, dtype: object

# %%
#laliga.groupby(['BestPosition'])['Points'].sum()

# %%
laliga['Points']=pd.to_numeric(laliga.Points)
laliga.groupby(['BestPosition'])['Points'].sum()
# Out:
# BestPosition
# 1     27933
# 10      450
# 11      445
# 12      511
# 14       71
# 15       14
# 16       81
# 17      266
# 19       81
# 2      6904
# 20       34
# 3      5221
# 4      6563
# 5      1884
# 6      2113
# 7      1186
# 8      1134
# 9        96
# Name: Points, dtype: int64
